# %%
# Dictionary untuk menyimpan data kursus
data_kursus = {
    'kursus': [
        {
            'id_kursus': 'KU001',
            'judul': 'Kursus ml',
            'tanggal': '2024-08-01',
            'lokasi': 'Jakarta',
            'instruktur': 'Andi Susanto',
            'peserta': [
                {
                    'id_peserta': 'P001',
                    'nama': 'Budi Santoso',
                    'jabatan': 'Manager'
                },
                {
                    'id_peserta': 'P002',
                    'nama': 'Siti Aminah',
                    'jabatan': 'Supervisor'
                }
            ]
        },
        {
            'id_kursus': 'KU002',
            'judul': 'Kursus Data Science',
            'tanggal': '2024-08-10',
            'lokasi': 'Bandung',
            'instruktur': 'Rina Andriana',
            'peserta': [
                {
                    'id_peserta': 'P003',
                    'nama': 'Dewi Sartika',
                    'jabatan': 'Staff'
                },
                {
                    'id_peserta': 'P004',
                    'nama': 'Tono Wijaya',
                    'jabatan': 'Manager'
                }
            ]
        }
    ]
}

# Menampilkan data kursus
print("Data Kursus:")
for kursus in data_kursus['kursus']:
    print(f"ID Kursus: {kursus['id_kursus']}")
    print(f"Judul Kursus: {kursus['judul']}")
    print(f"Tanggal: {kursus['tanggal']}")
    print(f"Lokasi: {kursus['lokasi']}")
    print(f"Instruktur: {kursus['instruktur']}")
    print("Peserta:")
    for peserta in kursus['peserta']:
        print(f"  ID Peserta: {peserta['id_peserta']}")
        print(f"  Nama: {peserta['nama']}")
        print(f"  Jabatan: {peserta['jabatan']}")
# Out:
# Data Kursus:
# ID Kursus: KU001
# Judul Kursus: Kursus ml
# Tanggal: 2024-08-01
# Lokasi: Jakarta
# Instruktur: Andi Susanto
# Peserta:
#   ID Peserta: P001
#   Nama: Budi Santoso
#   Jabatan: Manager
#   ID Peserta: P002
#   Nama: Siti Aminah
#   Jabatan: Supervisor
# ID Kursus: KU002
# Judul Kursus: Kursus Data Science
# Tanggal: 2024-08-10
# Lokasi: Bandung
# Instruktur: Rina Andriana
# Peserta:
#   ID Peserta: P003
#   Nama: Dewi Sartika
#   Jabatan: Staff
#   ID Peserta: P004
#   Nama: Tono Wijaya
#   Jabatan: Manager
